# %% [markdown]
# Cho một dãy số nguyên a gồm N phần tử và một số nguyên dương M (M < N).
# Ta có thể chia dãy a thành các mảng con liên tiếp, mỗi mảng con có độ dài đúng bằng M. Tổng cộng sẽ có N - M + 1 mảng con như vậy.
# Nhiệm vụ của bạn là tìm giá trị nhỏ nhất trong từng mảng con đó và in ra theo thứ tự từ trái sang phải.
#
# Dữ liệu vào (Input):
# Dòng 1: Chứa 2 số nguyên N và M cách nhau bởi dấu cách.
# Dòng 2: Chứa N số nguyên của mảng a, cách nhau bởi dấu cách.
#
# In ra N - M + 1 số nguyên trên một dòng, mỗi số cách nhau một dấu cách. Số thứ i là giá trị nhỏ nhất của mảng con thứ i.

# %% [markdown]
# Viết chương trình nhập vào ngày, tháng, năm sinh của hai người bạn. Hãy xác định xem ai là người sinh trước (lớn tuổi hơn).
# Dữ liệu vào (Input):
# - Dòng 1: Chứa 3 số nguyên d1, m1, y1 cách nhau bởi khoảng trắng, tương ứng là ngày, tháng, năm sinh của người thứ nhất.
# - Dòng 2: Chứa 3 số nguyên d2, m2, y2 cách nhau bởi khoảng trắng, tương ứng là ngày, tháng, năm sinh của người thứ hai.
# Dữ liệu ra (Output):
# - In ra số 1 nếu người thứ nhất sinh trước.
# - In ra số 2 nếu người thứ hai sinh trước.
# - In ra số 0 nếu hai người sinh cùng ngày, cùng tháng, cùng năm.

# %% [markdown]
# Cho list số nguyên không âm a. Sắp xếp tăng dần theo tổng chữ số; nếu bằng nhau thì theo giá trị tăng dần

# %% [markdown]
# Cho dãy số nguyên a và số nguyên x. Tìm giá trị v trong a có |v - x| nhỏ nhất. Nếu có nhiều giá trị cùng khoảng cách, chọn giá trị nhỏ hơn.

# %% [markdown]
# Cho list a và số nguyên k (1 ≤ k ≤ n). Trả về k phần tử lớn nhất theo thứ tự giảm dần
#
# Lưu ý: Không dùng hàm sort có sẵn

# %% [markdown]
# Viết hàm đệ quy count_digits(n) đếm số chữ số của n với n ≥ 0.
#
# Lưu ý: Không dùng các hàm có sẵn (len, str)

# %% [markdown]
# Cho chuỗi s. Kiểm tra s có phải palindrome sau khi loại bỏ khoảng trắng hay không (phân biệt hoa/thường giữ nguyên).
#
#
# Lưu ý: palindrome là một từ, số, cụm từ hoặc chuỗi ký hiệu khác đọc giống nhau khi đọc xuôi hoặc ngược

# %% [markdown]
# Cho list số nguyên a. Tính tổng các phần tử lẻ bằng đệ quy.

# %% [markdown]
# Viết hàm đệ quy count_digits(n) đếm số chữ số của n với n ≥ 0.
#
# Lưu ý: Không dùng các hàm có sẵn (len, str)

# %% [markdown]
# Cho chuỗi s. Kiểm tra s có phải palindrome sau khi loại bỏ khoảng trắng hay không (phân biệt hoa/thường giữ nguyên).
#
#
# Lưu ý: palindrome là một từ, số, cụm từ hoặc chuỗi ký hiệu khác đọc giống nhau khi đọc xuôi hoặc ngược

# %% [markdown]
# Cho list số nguyên a. Tính tổng các phần tử lẻ bằng đệ quy.

# %% [markdown]
# Cho list từ words (không rỗng). Tạo từ điển: key = chữ cái đầu, value = list các từ có chữ cái đầu đó, giữ nguyên thứ tự xuất hiện.

# %% [markdown]
# Cho danh sách records, mỗi phần tử là tuple (course, score) với score là số. Tạo dict ánh xạ course -> tổng score.

# %% [markdown]
# Cho list a. Trả về list các giá trị xuất hiện đúng 2 lần, theo thứ tự xuất hiện lần đầu trong a.

# %% [markdown]
# Mô tả bài toán:Viết hàm đệ quy thực hiện tính x lũy thừa n.
# Hàm cần xử lý được cả số mũ âm.
# Tối ưu hóa thời gian (độ phức tạp O(log n)).
#
# Input:
# x: Số thực (float).
# n: Số nguyên (integer).
#
# Output:
# Kết quả x^n (float).

# %% [markdown]
# Bạn đứng ở chân cầu thang gồm n bậc. Mỗi lần bạn có thể bước lên 1 bậc hoặc 2 bậc.
# Hãy tính số cách khác nhau để lên đúng bậc n.
#
# Input
# Một số nguyên dương n (1 ≤ n ≤ 45)
# Output
# Một số nguyên: số cách leo lên bậc n
# Ví dụ
# Input: 2 -> Output: 2 ( (1+1), (2) )
# Input: 3 -> Output: 3 ( (1+1+1), (1+2), (2+1) )

# %% [markdown]
# Kim cương là một tinh thể không màu được sản sinh ra từ cacbon nguyên chất trong tự nhiên. Kim cương có độ cứng 10 trên thang Mohs. Khoảng 49% kim cương được khai thác ở Trung Phi và Nam Phi, số khác được tìm thấy ở Canada, Ấn Độ, Nga, Brasil, Australia. Bốn nước sản xuất kim cương hàng đầu thế giới là Australia, Zaia, Botswana và Nga.
# Kim cương có nguồn gốc từ tiếng Hylạp (Adamas) tượng trưng cho sức mạnh và sự may mắn, kim cương có nhiều màu sắc rực rỡ như màu trắng, vàng nhạt, da cam, hồng, tím, xanh lá cây, xám đen… Nếu được chiếu dưới ánh sáng, những viên đá kim cương đa màu sắc sẽ tạo ra một vẻ đẹp lung linh huyền ảo.
# Kim cương là loại đá quý hiếm và đắt nhất trên thế giới, vì vậy con người luôn khát khao được sở hữu. Ngoài giá trị vật chất, kim cương còn là hiện thân của sức mạnh, quyền lực, sự giàu sang, lòng can đảm và là biểu tượng bất diệt của tình yêu.
# Hãy viết chương trình nhận vào từ bàn phím một số nguyên N và in ra một viên kim cương có kích thước (2N+1) x (2N+1).

# %% [markdown]
# Viết chương trình sử dụng khai triển Taylor để tính giá trị hàm mũ theo công thức sau:
# \( e^x = 1 + x + {x^2}/{2!} + {x^3}/{3!} + {x^4}/{4!} + {x^5}/{5!} + ... \)
# Sai số tới 0.001.
# Với x là số nguyên dương. Kết quả làm tròn đến số thập phân thứ tư.
# Gợi ý: sử dụng vòng lặp while và kiểm tra kiện (sum - sum_old > 0.001).

# %% [markdown]
# Bạn được cung cấp hai danh sách mã số sinh viên. Hãy trả về một danh sách kiểu str đã được sắp xếp gồm các mã số duy nhất xuất hiện trong một trong hai danh sách. (Sử dụng set)

# %% [markdown]
# Viết một chương trình Python cho phép người dùng nhập vào một số nguyên dương n và thực hiện các yêu cầu sau:
# Nếu đầu vào không phải số nguyên → báo lỗi: "Error: You should type an interger!"
# Nếu là số nguyên nhưng n ≤ 0 → báo lỗi: "Error: The number should larger than 0!"
# Nếu nhập đúng:
# Tính tổng các chữ số của n
# Tính giai thừa của n
# In kết quả ra màn hình
# Chương trình không được bị dừng đột ngột khi gặp lỗi, sử dụng try... exception, raise...

# %% [markdown]
# Cho hai mảng số nguyên list1 và list2.
# Hãy kiểm tra xem list1 có xuất hiện trong list2 như một dãy con liên tiếp (continuous subarray) hay không.
# Input
# Dòng 1: số nguyên n — số phần tử của list1
# Dòng 2: n số nguyên — các phần tử của list1
# Dòng 3: số nguyên m — số phần tử của list2
# Dòng 4: m số nguyên — các phần tử của list2
# Output
# In ra:
# YES nếu list1 là dãy con liên tiếp của list2
# NO nếu không phải

# %% [markdown]
# Cho một danh sách gồm n số nguyên, mỗi số nằm trong đoạn từ 0 đến 9.
# Hãy đếm số lần xuất hiện của từng chữ số và chỉ in ra những chữ số xuất hiện ít nhất 1 lần, theo thứ tự tăng dần của chữ số.
# Input
# Dòng 1: số nguyên n — số lượng phần tử.
# Dòng 2: n số nguyên a1 a2 ... an — mỗi ai thỏa 0 ≤ ai ≤ 9.
# Với mỗi chữ số d (từ 0 đến 9) có xuất hiện trong danh sách, in ra một dòng theo định dạng:
# d count
# trong đó count là số lần chữ số d xuất hiện.
# Các dòng phải được in theo thứ tự chữ số tăng dần.

# %% [markdown]
# Cho một dãy gồm n số nguyên. Hãy sắp xếp lại dãy theo các quy tắc sau:
# Tất cả số chẵn đứng trước, tất cả số lẻ đứng sau.
# Các số chẵn được sắp xếp tăng dần.
# Các số lẻ được sắp xếp giảm dần.
# Các phần tử được in ra theo thứ tự sau khi sắp xếp.
#
# Input
# Dòng 1: số nguyên n — số lượng phần tử trong dãy.
# Dòng 2: n số nguyên a1 a2 ... an.
# Output
# In ra dãy sau khi sắp xếp theo yêu cầu, các số cách nhau bởi dấu cách.

# %% [markdown]
# Bạn được cho một dictionary D có:
# key là chuỗi (không chứa khoảng trắng),
# value là số nguyên.
#
# Tiếp theo, bạn được cho một số nguyên k.
# Hãy tạo một dictionary mới R chỉ gồm những cặp (key, value) trong D mà value > k.
#
# Input
# Dòng 1: số nguyên n — số lượng cặp key-value trong dictionary.
# n dòng tiếp theo: mỗi dòng gồm key value
# key là chuỗi (không có khoảng trắng)
# value là số nguyên
# Dòng cuối: số nguyên k
# Output
# Nếu R rỗng: in ra EMPTY
# Ngược lại: in ra các cặp key value của R, mỗi cặp trên một dòng, theo thứ tự key tăng dần (từ điển).

# %% [markdown]
# Ta định nghĩa một kiểu dữ liệu thời gian Time gồm 3 thành phần số nguyên hour, minute, second.
#
# Khi tạo một class thời điểm Time(hour, minute, second), cần chuẩn hóa dữ liệu bằng cách:
# Dồn phần giây vượt 60 sang phút
# Dồn phần phút vượt 60 sang giờ
# Nếu giờ vượt 24 thì quy về trong một ngày (mod 24)
# Sau khi chuẩn hóa, so sánh hai thời điểm t1 và t2:
# t1 sớm hơn t2
# t2 sớm hơn t1
# hoặc bằng nhau
#
# Input
# Gồm 2 dòng:
# Dòng 1: hour minute second — thời điểm đến của Student 1
# Dòng 2: hour minute second — thời điểm đến của Student 2
# Output
# In Student 1 nếu Student 1 đến sớm hơn
# In Student 2 nếu Student 2 đến sớm hơn
# Nếu đến cùng thời điểm, in Equal

# %% [markdown]
# Máy tính đã “chọn sẵn” một số bí mật S trong đoạn 1..100.
# Bạn nhận được một danh sách các chuỗi mà người chơi đã nhập (có thể nhập sai, không phải số).
# Nhiệm vụ: mô phỏng trò chơi đoán số theo quy tắc sau (theo đúng thứ tự các dòng nhập):
# Với mỗi chuỗi x:
# Nếu x không chuyển được sang số nguyên (gây ValueError) hoặc số nằm ngoài [1, 100] → in Invalid
# Nếu chuyển được và value < S → in Too low
# Nếu chuyển được và value > S → in Too high
# Nếu value == S → in Correct và kết thúc ngay (không xử lý các dòng sau)
# Nếu hết danh sách mà chưa đoán đúng, in thêm một dòng Game Over.
# Yêu cầu bắt buộc: khi chuyển chuỗi sang số nguyên phải dùng try-except để bắt ValueError.
# Input
# Dòng 1: số nguyên S (1 ≤ S ≤ 100)
# Dòng 2: số nguyên n — số lượt nhập
# n dòng tiếp theo: mỗi dòng là một chuỗi người chơi nhập (có thể có khoảng trắng ở đầu/cuối)
# Output
# Với mỗi lượt (cho đến khi đúng hoặc hết lượt), in ra đúng một trong các dòng:
# Invalid, Too low, Too high, Correct
# Nếu không có Correct trong toàn bộ lượt, in thêm:
# Game Over

# %% [markdown]
# Viết chương trình nhập vào một ký tự duy nhất từ bàn phím. Hãy xác định ký tự đó thuộc nhóm nào trong 4 nhóm sau:
# - Chữ cái thường (a đến z)
# - Chữ cái in hoa (A đến Z)
# - Chữ số (0 đến 9)
# - Các ký tự khác (ký tự đặc biệt, khoảng trắng, dấu câu...)
# Dữ liệu vào (Input):
# Gồm 1 dòng chứa đúng một ký tự c.
# Dữ liệu ra (Output):
# In ra LOWER nếu là chữ thường.
# In ra UPPER nếu là chữ hoa.
# In ra DIGIT nếu là chữ số.
# In ra OTHER nếu là các loại ký tự khác.

# %% [markdown]
# Viết chương trình nhập vào một dãy số nguyên từ bàn phím (nhập từng số trên từng dòng). Quá trình nhập sẽ kết thúc ngay lập tức khi người dùng nhập vào số -1.
# Hãy tính giá trị: K = Tổng các số chẵn - Tổng các số lẻ.
# Lưu ý:
# Số -1 là dấu hiệu kết thúc, không được tính vào tổng lẻ hay kết quả cuối cùng.
# Số 0 được tính là số chẵn.
# Dãy số có thể bao gồm số âm.
# Dữ liệu vào (Input):
# Các số nguyên x, mỗi số trên một dòng (hoặc nhập liên tiếp). Kết thúc bởi số -1.
# Dữ liệu ra (Output):
# Một số nguyên duy nhất là kết quả của phép trừ.
# Một số nguyên duy nhất là kết quả của phép trừ.
