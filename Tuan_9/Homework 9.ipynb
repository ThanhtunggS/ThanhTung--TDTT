# %% [markdown]
# **Mã bài:** W9A16
# **Đề bài:** Cho hai số nguyên dương, n và m (0 < n, m <= 20). Bạn hãy in ra tất cả các chuỗi nhị phân có n số 0 và m số 1. In theo thứ tự tăng dần trong từ điển.

# %% [markdown]
# **Mã bài:** W9A17
# **Đề bài:** Viết hàm tìm dãy con tăng nghiêm ngặt dài nhất trong dãy đầu vào từ bàn phím.

# %% [markdown]
# **Mã bài:** W9A18
# **Đề bài:** Cho dãy N phần tử số nguyên, hãy đếm số cặp có vị trí khác nhau và có tổng bằng k (số nguyên dương cho vào từ bàn phím).

# %% [markdown]
# **Mã bài:** W9A19
# **Đề bài:** Loại bỏ khỏi danh sách các phần tử trùng lặp, giữ lại đúng 1 lần xuất hiện, in lại theo đúng thứ tự xuất hiện.

# %% [markdown]
# **Mã bài:** W9A20
# **Đề bài:** Thực hiện chuẩn hóa chuỗi kí tự:
# a. Bỏ khoảng trắng đầu cuối
# b. Các khoảng trắng giữa chỉ còn 1 dấu cách
# c. Viết hoa chữ cái đầu mỗi từ
# **Lưu ý:** KHÔNG DÙNG CÁC HÀM SẴN CÓ (như .strip(), .split(), .title() v.v. - hãy tự duyệt chuỗi bằng vòng lặp và xử lý thủ công).

# %% [markdown]
# **Mã bài:** W9A21
# **Đề bài:** Tìm phần tử lớn thứ k trong dãy n phần tử bằng thuật toán tốt nhất có thể – Tránh dùng sắp xếp (dùng phân hoạch của quicksort).

# %% [markdown]
# **Mã bài:** W9A22
# **Đề bài:** Hai chuỗi là anagram nếu chúng có cùng ký tự và số lần xuất hiện. Viết chương trình kiểm tra xem 2 chuỗi đầu vào có phải là anagram của nhau không.

# %% [markdown]
# **Mã bài:** W9A23
# **Đề bài:** Cho số nguyên rất lớn (string), và một số nguyên dương k. Tìm số có k chữ số lớn nhất có thể từ số ban đầu bằng cách xóa bớt đi một số chữ số nào đó mà không thay đổi vị trí của bất kì chữ số nào. (Ví dụ: 78934340999, k = 7 => 9440999 là số lớn nhất có 7 chữ số cần tìm).

# %% [markdown]
# **Mã bài:** W9A24
# **Đề bài:** Nén chuỗi kí tự bằng cách đếm số lần xuất hiện của các kí tự liên tiếp nhau và ghi lại ngay sau kí tự đó. Ví dụ: aaaaaafdhhhhh => a6f1d1h5.

# %% [markdown]
# **Mã bài:** W9A25
# **Đề bài:** Giả sử mật khẩu mạnh là một chuỗi kí tự dài ít nhất 8 kí tự gồm ít nhất 1 chữ cái thường, 1 chữ cái hoa, 1 chữ số và 1 trong các kí tự đặc biệt !, @, #, $. Nhập vào một chuỗi kí tự, kiểm tra xem nó có phải là mật khẩu mạnh không.
